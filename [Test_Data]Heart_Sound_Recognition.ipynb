# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# REFERENSI :
#
# https://physionet.org/content/challenge-2016/1.0.0/papers/langley.pdf
# https://physionet.org/content/challenge-2016/1.0.0/papers/grzegorczyk.pdf
# https://physionet.org/files/challenge-2016/1.0.0/papers/index.html
# https://www.researchgate.net/publication/228412447_Frequency_analysis_of_the_heartbeat_sounds

# %%
# !cd "/content/drive/My Drive/DataSetSuaraJantungPhysionet/" && wget -r -N -c -np "https://physionet.org/files/challenge-2016/1.0.0/"

# %%
import librosa

# %%
sampelfile="/content/drive/My Drive/DataSetSuaraJantungPhysionet/challenge-2016/1.0.0/training-a/a0001.wav"
x,sr=librosa.load(sampelfile)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display

plt.figure(figsize=(14, 5))
librosa.display.waveplot(x[:sr*5], sr=sr)

# %%
import IPython.display as ipd
ipd.Audio(x[:sr*5], rate=sr) # load a NumPy array
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
